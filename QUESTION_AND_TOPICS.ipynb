# %% [markdown]
# ### Command line
# - customize shell prompt (add time for example)
# - alias and persistent aliases
# - variables and persistent variables (.bash_profile)
# - find/locate difference
# - cut, sort, grep (-v, o, -E, -i)
# - awk, sed
# - wildcards, regular expressions, extended globbing
# - find by filename or inside file content
# - redirection (stdin, stdout, stderr)
# - !! - last command, !chm - last starting with chm, $$ - curr process, !* - args from prev. command, !$ - last item on prev. command
# - visudo for /etc/sudoers file
# - history: HISTSIZE, reverse&search(ctrl + r), !!, !l, !ech, !:2, !^, !$
#
# ### Files
# - tar: compress, uncompress, list content
#
# ### Users and groups
# - umask (make permanent)
# - switching users: sudo, su, su - , sudo su -, sudo su difference
# - /etc/passwd, /etc/shadow, /etc/login.defs, /etc/skel (shell config files)
# - useradd -d -r(system acc) -c -u
# - suid (4770), sgid (2770), sticky bit (1770)
# - ACL
#
# ### System administration
# - boot process
#   - BIOS (basic i/o/system; find and execute boot loader, POST)
#   - Boot loaders (LILO, GRUB)
#   - /boot $ - $ initrd, kernel, boot loader config
#   - initrd $ - $ initial RAM disk (temp. filesystem; helpers and modules to run permanent OS)
#   - vmlinux, vmlinuz
#   - dmesg (/var/log/dmesg) $ - $ kernel ring buffer
#   - runlevels (0-6), init (/etc/inittab)
#     - telinit RUNLEVEL
#   - systemctl (systemd), targets instead of runlevels (available: /lib/systemd/system)
#     - systemctl get-default
#     - systemctl set-default graphical.target
#     - systemctl isolate TARGET
#   - shutdown (shutdown -r +5 "rebooting soon!"), reboot (init 6, systemctl isolate reboot.target), poweroff (init 0, systemctl isolate poweroff.target)
# - logging
#   - FACILITY.SEVERITY
#   - rsyslog
#     - /etc/rsyslog.conf
#     - mail.* /var/log/mail.log
#     - mail.info -/var/log/mail.info
#     - auth,authpriv.* /var/log/auth.log
#     - *.info;mail.none;cron.none /var/log/messages
#     - caching/non-caching
#   - logger
#     - logger -p mail.info -t mailtest "Test"
#     - tail -1 /var/log/mail.log
#   - logrotate
#     - for saving and compress log files
#     - /etc/logrotate.conf
#     - logrotate -fv /etc/logrotate.conf
# - managing disks and fs
# - software: rpm, yum, dnf, (search, info, list files, rpm -qa, -qf, -ivh (install), -e (uninstall), ), (dqkg -i -r -L), (apt search purge update upgrade)
# - nginx
#   - curl http//:localhost
# - mysql-server
#   - mysqladmin create wordpress
#   - mysql
#   - CREATE USER wordpress@localhost identified by 'word123'
#   - GRANT ALL on wordpress.* to ...@...
#   - mysql -u wordpress -p wordpress
#   - SET PASSWORD for ...@... = '...'
# - php-fpm php-mysql php-curl php-mbstring php-imagick php-xml
#   - /etc/nginx/sites-available
#   - add index.php
#   - add /index.php$is_args$args
#   - uncomment location php
#   - nginx -t $ - $ check for errors
#   - download wordpress tar and untar it
#   - mv wordpress/* /var/www/html
#   - chown -R www-data:www-data /var/www/html
#   - my_ip/wp-admin/setup-config.php
# - uname -m $ - $ architecture
# - apt autoremove  $ - $ delete unused dependencies
#
# ###Networking
# - transfer: scp, sftp, ftp
#
# ### System automation
# - jobs, fg, bg, jobs %1, kill
# - ps, ps -ef, ps --forest, ps aux
# - crontab cron_file, crontab -l
# - top, htop
